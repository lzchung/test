# %% [markdown]
# <a href="https://colab.research.google.com/github/lzchung/test/blob/main/image_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Nvidia info T4/A100/V100")
# !nvidia-smi

print("CPU status")
# !cat /proc/cpuinfo | grep 'model name' #檢查CPU資訊

print("\nHard disk info")
# !df -lh #檢查disk空間

print("\n檢查記憶體空間")
# !free -h #檢查記憶體使用狀況
# Out:
# Nvidia info T4/A100/V100
# /bin/bash: line 1: nvidia-smi: command not found
# CPU status
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
#
# Hard disk info
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   32G   76G  30% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.8G     0  5.8G   0% /dev/shm
# /dev/root       2.0G  1.1G  849M  57% /usr/sbin/docker-init
# tmpfs           6.4G   52K  6.4G   1% /var/colab
# /dev/sda1        70G   43G   27G  62% /kaggle/input
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# drive           108G   36G   73G  34% /content/drive
#
# 檢查記憶體空間
#                total        used        free      shared  buff/cache   available
# Mem:            12Gi       531Mi       8.5Gi       1.0Mi       3.6Gi        11Gi
# Swap:             0B          0B          0B

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# #灰階
# img0 = cv2.imread('/content/drive/MyDrive/image1.jpg', cv2.IMREAD_GRAYSCALE)  # 0 for grayscale
#
# plt.imshow(img0, cmap='gray')
# plt.show()

# %%
img = cv2.imread('/content/drive/MyDrive/lena.jpg')

width, height, channel = img.shape  # 列*行*頻道數

print(img.shape)
print(f'P[100][100]={img[100][100]}')
img[100][100]=[50, 60, 70]
print(f'P[100][100]={img[100][100]}')
# Out:
# (316, 316, 3)
# P[100][100]=[114 114 214]
# P[100][100]=[50 60 70]

# %%
# method1 BGR TO BGR

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow( img )

plt.show()

# %%
scale_percent = 200       # percent of original size

width  = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)

dim = (width, height)



img1 = cv2.resize(img, dim, interpolation=cv2.INTER_NEAREST)
img2 = cv2.resize(img, dim, interpolation=cv2.INTER_LINEAR)
img3 = cv2.resize(img, dim, interpolation=cv2.INTER_AREA)
img4 = cv2.resize(img, dim, interpolation=cv2.INTER_CUBIC)
img5 = cv2.resize(img, dim, interpolation=cv2.INTER_LANCZOS4)

titles = ['Original Image', 'INTER_NEAREST', 'INTER_LINEAR', 'INTER_AREA', 'INTER_CUBIC', 'INTER_LANCZOS4']
images = [img, img1, img2, img3, img4, img5]

'''
for i in range(6):
    #plt.subplot(2, 3, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
    plt.show()
'''

for i in range(6):
    plt.subplot(2, 3, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
plt.show()

# %%
import scipy

# %%
print( scipy.special.comb(10, 3) )
# Out:
# 120.0
